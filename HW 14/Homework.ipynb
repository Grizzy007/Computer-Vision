# %% [markdown]
# # HOMEWORK 14
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 15s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 2s 1us/step
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,213,002
# Trainable params: 3,213,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.3938 - accuracy: 0.8613 - val_loss: 0.3284 - val_accuracy: 0.8814
# Epoch 2/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.2710 - accuracy: 0.9035 - val_loss: 0.3011 - val_accuracy: 0.8909
# Epoch 3/50
# 938/938 [==============================] - 34s 37ms/step - loss: 0.2320 - accuracy: 0.9161 - val_loss: 0.3016 - val_accuracy: 0.8954
# Epoch 4/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.2009 - accuracy: 0.9265 - val_loss: 0.2997 - val_accuracy: 0.8977
# Epoch 5/50
# 938/938 [==============================] - 37s 40ms/step - loss: 0.1789 - accuracy: 0.9348 - val_loss: 0.3137 - val_accuracy: 0.8982
# Epoch 6/50
# 938/938 [==============================] - 34s 37ms/step - loss: 0.1613 - accuracy: 0.9410 - val_loss: 0.3232 - val_accuracy: 0.8974
# Epoch 7/50
# 938/938 [==============================] - 33s 36ms/step - loss: 0.1439 - accuracy: 0.9468 - val_loss: 0.3335 - val_accuracy: 0.8987
# Epoch 8/50
# 938/938 [==============================] - 33s 35ms/step - loss: 0.1333 - accuracy: 0.9516 - val_loss: 0.3633 - val_accuracy: 0.8959
# Epoch 9/50
# 938/938 [==============================] - 33s 35ms/step - loss: 0.1190 - accuracy: 0.9567 - val_loss: 0.3886 - val_accuracy: 0.8948
# Epoch 10/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.1071 - accuracy: 0.9603 - val_loss: 0.4164 - val_accuracy: 0.8896
# Epoch 11/50
# 938/938 [==============================] - 33s 35ms/step - loss: 0.0961 - accuracy: 0.9647 - val_loss: 0.4210 - val_accuracy: 0.8960
# Epoch 12/50
# 938/938 [==============================] - 34s 37ms/step - loss: 0.0886 - accuracy: 0.9674 - val_loss: 0.4339 - val_accuracy: 0.8921
# Epoch 13/50
# 938/938 [==============================] - 35s 37ms/step - loss: 0.0792 - accuracy: 0.9715 - val_loss: 0.4730 - val_accuracy: 0.8921
# Epoch 14/50
# 938/938 [==============================] - 38s 40ms/step - loss: 0.0711 - accuracy: 0.9742 - val_loss: 0.4960 - val_accuracy: 0.8936
# Epoch 15/50
# 938/938 [==============================] - 39s 41ms/step - loss: 0.0651 - accuracy: 0.9758 - val_loss: 0.5458 - val_accuracy: 0.8879
# Epoch 16/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.0611 - accuracy: 0.9780 - val_loss: 0.5742 - val_accuracy: 0.8915
# Epoch 17/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.0557 - accuracy: 0.9797 - val_loss: 0.5976 - val_accuracy: 0.8914
# Epoch 18/50
# 938/938 [==============================] - 33s 36ms/step - loss: 0.0535 - accuracy: 0.9809 - val_loss: 0.6008 - val_accuracy: 0.8948
# Epoch 19/50
# 938/938 [==============================] - 33s 35ms/step - loss: 0.0483 - accuracy: 0.9824 - val_loss: 0.6357 - val_accuracy: 0.8932
# Epoch 20/50
# 938/938 [==============================] - 33s 35ms/step - loss: 0.0424 - accuracy: 0.9849 - val_loss: 0.6618 - val_accuracy: 0.8930
# Epoch 21/50
# 938/938 [==============================] - 33s 35ms/step - loss: 0.0450 - accuracy: 0.9835 - val_loss: 0.7215 - val_accuracy: 0.8859
# Epoch 22/50
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0400 - accuracy: 0.9859 - val_loss: 0.7606 - val_accuracy: 0.8861
# Epoch 23/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.0403 - accuracy: 0.9852 - val_loss: 0.7832 - val_accuracy: 0.8817
# Epoch 24/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.0348 - accuracy: 0.9873 - val_loss: 0.7785 - val_accuracy: 0.8875
# Epoch 25/50
# 938/938 [==============================] - 41s 43ms/step - loss: 0.0325 - accuracy: 0.9882 - val_loss: 0.7962 - val_accuracy: 0.8899
# Epoch 26/50
# 938/938 [==============================] - 38s 41ms/step - loss: 0.0337 - accuracy: 0.9882 - val_loss: 0.8684 - val_accuracy: 0.8817
# Epoch 27/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.0323 - accuracy: 0.9886 - val_loss: 0.8166 - val_accuracy: 0.8883
# Epoch 28/50
# 938/938 [==============================] - 37s 40ms/step - loss: 0.0302 - accuracy: 0.9893 - val_loss: 0.8574 - val_accuracy: 0.8887
# Epoch 29/50
# 938/938 [==============================] - 38s 41ms/step - loss: 0.0271 - accuracy: 0.9902 - val_loss: 0.8725 - val_accuracy: 0.8856
# Epoch 30/50
# 938/938 [==============================] - 40s 43ms/step - loss: 0.0278 - accuracy: 0.9900 - val_loss: 0.9495 - val_accuracy: 0.8912
# Epoch 31/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.0243 - accuracy: 0.9910 - val_loss: 0.9605 - val_accuracy: 0.8838
# Epoch 32/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.0257 - accuracy: 0.9911 - val_loss: 0.9760 - val_accuracy: 0.8846
# Epoch 33/50
# 938/938 [==============================] - 37s 40ms/step - loss: 0.0208 - accuracy: 0.9924 - val_loss: 0.9915 - val_accuracy: 0.8875
# Epoch 34/50
# 938/938 [==============================] - 35s 37ms/step - loss: 0.0238 - accuracy: 0.9916 - val_loss: 0.9592 - val_accuracy: 0.8867
# Epoch 35/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.0245 - accuracy: 0.9910 - val_loss: 1.0625 - val_accuracy: 0.8861
# Epoch 36/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.0252 - accuracy: 0.9912 - val_loss: 1.0331 - val_accuracy: 0.8865
# Epoch 37/50
# 938/938 [==============================] - 35s 37ms/step - loss: 0.0208 - accuracy: 0.9924 - val_loss: 1.0223 - val_accuracy: 0.8887
# Epoch 38/50
# 938/938 [==============================] - 33s 36ms/step - loss: 0.0228 - accuracy: 0.9915 - val_loss: 1.0539 - val_accuracy: 0.8856
# Epoch 39/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.0179 - accuracy: 0.9933 - val_loss: 1.0617 - val_accuracy: 0.8896
# Epoch 40/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.0225 - accuracy: 0.9923 - val_loss: 1.1238 - val_accuracy: 0.8823
# Epoch 41/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.0194 - accuracy: 0.9929 - val_loss: 1.1307 - val_accuracy: 0.8818
# Epoch 42/50
# 938/938 [==============================] - 33s 36ms/step - loss: 0.0186 - accuracy: 0.9939 - val_loss: 1.0749 - val_accuracy: 0.8879
# Epoch 43/50
# 938/938 [==============================] - 34s 37ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 1.1527 - val_accuracy: 0.8871
# Epoch 44/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.0163 - accuracy: 0.9941 - val_loss: 1.1241 - val_accuracy: 0.8851
# Epoch 45/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.0186 - accuracy: 0.9939 - val_loss: 1.1700 - val_accuracy: 0.8868
# Epoch 46/50
# 938/938 [==============================] - 35s 37ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 1.1783 - val_accuracy: 0.8907
# Epoch 47/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 1.1589 - val_accuracy: 0.8924
# Epoch 48/50
# 938/938 [==============================] - 40s 42ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 1.2805 - val_accuracy: 0.8881
# Epoch 49/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 1.2798 - val_accuracy: 0.8849
# Epoch 50/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 1.2356 - val_accuracy: 0.8901

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.9950166940689087
# Validation Acc 0.8901000022888184

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

inputs = Input(shape=(28, 28, 1))

net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)

net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)

net = Flatten()(net)
net = Dense(128, activation="relu")(net)
net = BatchNormalization()(net)

outputs = Dense(10, activation="softmax")(net)

model2 = Model(inputs, outputs)
model2.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 32)        320
#
#  batch_normalization_9 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 64)        18496
#
#  batch_normalization_10 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 3136)              0
#
#  dense_8 (Dense)             (None, 128)               401536
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 422,538
# Trainable params: 422,090
# Non-trainable params: 448
# _________________________________________________________________

# %%
# Train the network
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

epochs = 30
batch_size = 256

early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr  = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

x_train_4d = x_train.reshape(-1, 28, 28, 1)
x_test_4d  = x_test.reshape(-1, 28, 28, 1)

model2.compile(loss="sparse_categorical_crossentropy",
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
               metrics=["accuracy"])

history2 = model2.fit(
    x_train_4d, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test_4d, y_test),
    callbacks=[early_stop, reduce_lr],
)

# %%
# Show the results
plot_history(history2)
# Out:
# Train Acc      0.8825333118438721
# Validation Acc 0.8587999939918518

# %% [markdown]
# ### Questions
#
# * What have you done in order to improve the performance?
# * Have you tried configurations that did not work out?
